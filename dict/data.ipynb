# %%
# Dictionaries 



# creation 


my_dict = dict(one ="one", two ="two", three = 'three')

print(my_dict)

s_dict = {"name": "Nithin", "age": 23, "role":"Student"}

print(s_dict)


t_dict = dict([("one","one"),("two","two")])
print(t_dict)



# access

print(my_dict["one"])


#update 

my_dict["one"] = "One"

print(my_dict)

# travers


for key in s_dict:
    print(key, s_dict[key])



# search 

for key in s_dict:
    if (s_dict[key]== "Nithin"):
        print("Found")




# delete 


del my_dict["one"]
print(my_dict)


popped_value = my_dict.pop("two")

print(popped_value)
print(my_dict)



# clear


# dict methods - clear, copy, fromkeys(), get()

a = {"a":'a'}
print(a)

a.clear()
print(a)


b= {"a":"a", "b":"b"}

c = b.copy()

print(c)
print(b)

b["b"] = "c"

print(b)
print(c)


c["a"] = "k"

print(c)
print(b)


# fromkeys

j = [0,1,2]

k = {}.fromkeys(j, None)
print(k)

l = dict.fromkeys(j, 0)

print(l)

print(s_dict.get("name"))
print(s_dict.get("role"))
print(s_dict.get("gender", "male"))

print(s_dict.keys())
print(s_dict.values())
print(s_dict.items())


for i in s_dict.items():
    print(i)


o = {"a":"a"}

o.update(dict([("b","b")]))

print(o)
# Out:
# {'one': 'one', 'two': 'two', 'three': 'three'}
# {'name': 'Nithin', 'age': 23, 'role': 'Student'}
# {'one': 'one', 'two': 'two'}
# one
# {'one': 'One', 'two': 'two', 'three': 'three'}
# name Nithin
# age 23
# role Student
# Found
# {'two': 'two', 'three': 'three'}
# two
# {'three': 'three'}
# {'a': 'a'}
# {}
# {'a': 'a', 'b': 'b'}
# {'a': 'a', 'b': 'b'}
# {'a': 'a', 'b': 'c'}
# {'a': 'a', 'b': 'b'}
# {'a': 'k', 'b': 'b'}
# {'a': 'a', 'b': 'c'}
# {0: None, 1: None, 2: None}
# {0: 0, 1: 0, 2: 0}
# Nithin
# Student
# male
# dict_keys(['name', 'age', 'role'])
# dict_values(['Nithin', 23, 'Student'])
# dict_items([('name', 'Nithin'), ('age', 23), ('role', 'Student')])
# ('name', 'Nithin')
# ('age', 23)
# ('role', 'Student')
# {'a': 'a', 'b': 'b'}
# None

# %%
a ={"a":"a",'B':"b"}

for key,value in enumerate(a):
    print(key,a[value])
# Out:
# 0 a
# 1 b

# %%
# Define a function to count the frequency of words in a given list of words.

# Example:

# words = ['apple', 'orange', 'banana', 'apple', 'orange', 'apple'] 
# count_word_frequency(words) 
# Output:

#  {'apple': 3, 'orange': 2, 'banana': 1}



def count_word_frequency(words):
    seen ={}


    for value in words:
        if value not in seen:
            seen[value] = 1
        else:
            seen[value] +=1

    return seen


print(count_word_frequency(['apple', 'orange', 'banana', 'apple', 'orange', 'apple'] ))
# Out:
# {'apple': 3, 'orange': 2, 'banana': 1}

# %%
# Common Keys
# Define a function with takes two dictionaries as parameters and merge them and sum the values of common keys.

# Example:

# dict1 = {'a': 1, 'b': 2, 'c': 3}
# dict2 = {'b': 3, 'c': 4, 'd': 5}
# merge_dicts(dict1, dict2)
# Output:

# {'a': 1, 'b': 5, 'c': 7, 'd': 5}



def common_keys(dict1, dict2):
    result ={}

    unique_keys = set(dict1) | set(dict2)

    for key in unique_keys:
        result[key] = dict1.get(key,0) + dict2.get(key, 0)


    return result


print(common_keys({'a': 1, 'b': 2, 'c': 3},{'b': 3, 'c': 4, 'd': 5}))
# Out:
# {'b': 5, 'a': 1, 'd': 5, 'c': 7}
